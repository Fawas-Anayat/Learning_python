# %% [markdown]
# # Basics
# This file contains all the practice code written for revsing all the basics of the python

# %% [markdown]
# ### Python match statments
# same as the switch statement of the C++

# %%
day=2
match day:
    case 1:
        print("monday")
    case 2:
        print("tuesday")
    case 3:
        print("wednesday")
# Out:
# tuesday

# %%
def add_numbers(*args):
    """args (arbitrary arguments) are when we don't know how many values will be passed and args is a tuple"""
    total=0
    for num in args:
        total+=num
    print(f"the total is {total}")
add_numbers(100,101)
help(add_numbers)
# Out:
# the total is 201
# Help on function add_numbers in module __main__:
#
# add_numbers(*args)
#     args are when we don't know how many values will be passed and args is a tuple

# %%
def details(**kwargs):
    """kwargs (key word arbitrary arguments) is used for dynamic named arguments and its a dictionary"""
    for key,val in kwargs.items():
        print(key,val)
help(details)
details(name="fawas",age=22,college="gpgc")
# Out:
# Help on function details in module __main__:
#
# details(**kwargs)
#     kwargs is used for dynamic named arguments and its a dictionary
#
# name fawas
# age 22
# college gpgc

# %%
dic={
    'name':"fawas",
    'college':"gpgc"
}
print(type(dic))
# Out:
# <class 'dict'>

# %% [markdown]
# # Decorators
# its a special kind of function in python that takes a function as an input and then return another function
# A decorator recieves the function objects not the return values. If we want to recieve the return value we will have to call the function

# %%
def change_case(fun):
    def change():
        return fun().upper()
    return change

@change_case
def name():
    return "fawas anayat"
print(name())
# Out:
# FAWAS ANAYAT

# %%
def combine(f1):
    def decorator(f2):
        def add():
            return f2() +" "+ f1()
        return add
    return decorator

def sec_name():
    return "anayat"

@combine(sec_name)
def first_name():
    return "fawas"

print(first_name())
# Out:
# fawas anayat

# %% [markdown]
# ## Lambda Functions
# A small anonymous(does not need a name) function that takes any number of arguments and have just one expresssion.
# used for the short operations

# %%
fun=lambda x:x*10
print(fun(10))
# Out:
# 100

# %%
l=[23,45,56,67,88]
a=list(map(lambda num:num*num,l))
print(a)
# Out:
# [529, 2025, 3136, 4489, 7744]
